# %%
import pandas as pd 
import matplotlib as plt

data={
    "Day":[1,2,3,4,5],
    "Users":[120,150,170,160,180],
    "Purchase":[30,35,40,38,45]
}

df=pd.DataFrame(data)
print(df)
# Out:
#    Day  Users  Purchase
# 0    1    120        30
# 1    2    150        35
# 2    3    170        40
# 3    4    160        38
# 4    5    180        45
