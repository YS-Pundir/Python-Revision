# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
data={
    "epchos":range(1,11),
    "Loss":[0.6,0.7,0.88,0.2,0.79,0.4,0.5,0.1,0.3,0.9]
    
    }

df=pd.DataFrame(data)

# %%
#

# %%
data={
    "user":[3,5,7,2,8,9],
    "Perchase":[21,45,97,56,89,32]
}
df=pd.DataFrame(data)

fig=px.scatter(df,x=df["user"],y="Perchase",title="Perchase Analysis")
fig.show()

# %%
df_cluster=pd.DataFrame({
    "x":np.random.rand(100),
    "y":np.random.rand(100),
    "group":np.random.choice(["A","B","C"],100)
})
print("The dataset is : ")
print(df_cluster)
## creat6ed a dataset and assigned a group to each row randomely

fig=px.scatter(df_cluster,x='x',y="y",color="group",title="Cluster Visulaisation",color_discrete_sequence=["red","blue","green"] )

fig.show()
# Out:
# The dataset is :
#            x         y group
# 0   0.659349  0.595796     A
# 1   0.186115  0.720134     C
# 2   0.292763  0.866850     C
# 3   0.160868  0.905547     A
# 4   0.742728  0.823376     A
# ..       ...       ...   ...
# 95  0.128581  0.853411     B
# 96  0.788337  0.440253     C
# 97  0.562875  0.836286     A
# 98  0.754711  0.260207     C
# 99  0.693495  0.653715     A
#
# [100 rows x 3 columns]

# %%
df_cluster=pd.DataFrame({
    "x":np.random.rand(100),
    "y":np.random.rand(100),
    "group":np.random.choice(["A","B","C"],100)
})
print("The dataset is : ")
print(df_cluster)
## creat6ed a dataset and assigned a group to each row randomely

fig=px.scatter(df_cluster,x='x',y="y",color="group",title="Cluster Visulaisation",color_discrete_map={
    "A":"red",
    "B":"blue",
    "C":"Green"

} )
fig.write_image("PLot3.png")
fig.show()
# Out:
# The dataset is :
#            x         y group
# 0   0.925286  0.256281     B
# 1   0.059358  0.764200     B
# 2   0.823779  0.880499     B
# 3   0.579813  0.411316     C
# 4   0.472473  0.876930     C
# ..       ...       ...   ...
# 95  0.278155  0.261053     C
# 96  0.485278  0.940631     A
# 97  0.372969  0.084364     C
# 98  0.979883  0.672729     A
# 99  0.531181  0.649694     B
#
# [100 rows x 3 columns]

# %%
df_model=pd.DataFrame({
    "Model":["Model 1","Model 2","Model 3"],
    "Accuracy":[0.65,0.90,0.77]

})

fig=px.bar(df_model,x=df_model["Model"],y=df_model["Accuracy"],title="Modle accuracy comparison",color=["red","green","blue"])
fig.write_image("plot2.png")
fig.show()

# %%
df=pd.DataFrame({
    "Age":[22,25,26,28,30,31,36,78,42,89,65,24,76]
})

fig=px.histogram(x=df["Age"],title="Age Distribution")
# fig=px.histogram(x=df["Age"],title="Age Distribution",nbins=4)
#usse nbins when we need to give control to the ssystem    on choosing the grouping 
# use xbins  when we want to hae control
fig.update_traces(
    xbins={
        "start":18,
        "end":50,
        "size":8
    
    }
)

fig.show()

# %%
## Annotation
data={
    "epchos":range(1,11),
    "Loss":[0.6,0.7,0.88,0.2,0.79,0.4,0.5,0.1,0.3,0.9]
    
    }

df=pd.DataFrame(data)
fig=px.line(df,x=df["epchos"],y=df["Loss"],title="Training loss over time")
fig.add_annotation(
    x=5,
    y=0.79,
    text="Main Point",
    showarrow=True,
    arrowhead=6
)
fig.show()

# %%
# usingh the klaeido library , saving the plot.img image
fig.write_image("plot.png")
