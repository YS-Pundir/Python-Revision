# %%
import plotly.express as px
import pandas as pd

# %%
data={
    "epchos":range(1,11),
    "Loss":[0.6,0.7,0.88,0.2,0.79,0.4,0.5,0.1,0.3,0.9]
    
    }

df=pd.DataFrame(data)
# Out:
#    epchos  Loss
# 0       1  0.60
# 1       2  0.70
# 2       3  0.88
# 3       4  0.20
# 4       5  0.79
# 5       6  0.40
# 6       7  0.50
# 7       8  0.10
# 8       9  0.30
# 9      10  0.90
