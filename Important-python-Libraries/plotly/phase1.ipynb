# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
data={
    "epchos":range(1,11),
    "Loss":[0.6,0.7,0.88,0.2,0.79,0.4,0.5,0.1,0.3,0.9]
    
    }

df=pd.DataFrame(data)
# Out:
#    epchos  Loss
# 0       1  0.60
# 1       2  0.70
# 2       3  0.88
# 3       4  0.20
# 4       5  0.79
# 5       6  0.40
# 6       7  0.50
# 7       8  0.10
# 8       9  0.30
# 9      10  0.90

# %%
fig=px.line(df,x=df["epchos"],y=df["Loss"],title="Training loss over time")
fig.show()

# %%
data={
    "user":[3,5,7,2,8,9],
    "Perchase":[21,45,97,56,89,32]
}
df=pd.DataFrame(data)

fig=px.scatter(df,x=df["user"],y="Perchase",title="Perchase Analysis")
fig.show()

# %%
df_cluster=pd.DataFrame({
    "x":np.random.rand(100),
    "y":np.random.rand(100),
    "group":np.random.choice(["A","B","C"],100)
})
print("The dataset is : ")
print(df_cluster)
## creat6ed a dataset and assigned a group to each row randomely

fig=px.scatter(df_cluster,x='x',y="y",color="group",title="Cluster Visulaisation",color_discrete_sequence=["red","blue","green"] )

fig.show()
# Out:
# The dataset is :
#            x         y group
# 0   0.667152  0.992558     C
# 1   0.322952  0.831314     A
# 2   0.677678  0.079330     C
# 3   0.781639  0.677597     B
# 4   0.668795  0.579069     B
# ..       ...       ...   ...
# 95  0.854906  0.403334     C
# 96  0.826504  0.501122     B
# 97  0.606494  0.603659     A
# 98  0.092952  0.920411     B
# 99  0.474254  0.880788     C
#
# [100 rows x 3 columns]

# %%
df_cluster=pd.DataFrame({
    "x":np.random.rand(100),
    "y":np.random.rand(100),
    "group":np.random.choice(["A","B","C"],100)
})
print("The dataset is : ")
print(df_cluster)
## creat6ed a dataset and assigned a group to each row randomely

fig=px.scatter(df_cluster,x='x',y="y",color="group",title="Cluster Visulaisation",color_discrete_map={
    "A":"red",
    "B":"blue",
    "C":"Green"

} )

fig.show()
# Out:
# The dataset is :
#            x         y group
# 0   0.655673  0.052938     A
# 1   0.321154  0.754504     B
# 2   0.689856  0.801338     C
# 3   0.973985  0.039132     A
# 4   0.921654  0.473382     A
# ..       ...       ...   ...
# 95  0.592931  0.486386     A
# 96  0.484809  0.178103     B
# 97  0.614001  0.687249     A
# 98  0.907481  0.962017     C
# 99  0.326028  0.467365     A
#
# [100 rows x 3 columns]
