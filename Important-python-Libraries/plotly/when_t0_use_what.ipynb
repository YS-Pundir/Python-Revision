# %% [markdown]
# ### Line Chart :
#         use line chart when showing the trends .
#
#             1. Montly revenue
#             2. model training progress .
# ### Scatter plot :
#             1. predicted v/s actuall values .
#             2. when there is some corelation in some sort of data .
# ### Bar :
#             1. we use bar chart during the comparisons
#             2. model performance comparison .
#             3. inventory count .
#             4. there are categories as data tyoes in bar chart .
#             5. the perpose is the comparison
# ### Histogram :
#              1. there aare mostly numerical ranges as datatype in histogram.
#              2. the perpose is to distribute .
#              3. bars usually tiouches each others .
