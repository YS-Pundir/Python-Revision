# %%
# creating a Dataframe 
Student={
    "ID":[1,2,3,4,5,6],
    "Name":["Yuvraj Singh","Arpanjeet Singh","Ramesh Choudhry","Rama Krishna","Rohit saini","Mohit Pundir"],
    "Course":["Software Engineering","Electrical Engineering","Mechanical Engineering","BioTech Management","Chemical Engineering","Aerotech Engineering"],
    "City":["Delhi","Chandigarh","Amritsar","Mumbai","Channai","Bangluru"],
    "Age":[18,19,25,22,20,18]
    
}

# %%
import pandas as pd

# %%
df=pd.DataFrame(Student)
df.to_csv("Student.csv")

# %%
print(f"First five columns of the dataframe : ")
print(f"{df.head()}")
print(f"The last five columns of the dataframe : ")
print(f" {df.tail()}")
print(f"Structural Information about the DataFrame : ")
print(f"{df.info()}")
print(f"Statistical Summary of DataFrame : ")
print(f" {df.describe()}")
# Out:
# First five columns of the dataframe :
#    ID             Name                  Course        City  Age
# 0   1     Yuvraj Singh    Software Engineering       Delhi   18
# 1   2  Arpanjeet Singh  Electrical Engineering  Chandigarh   19
# 2   3  Ramesh Choudhry  Mechanical Engineering    Amritsar   25
# 3   4     Rama Krishna      BioTech Management      Mumbai   22
# 4   5      Rohit saini    Chemical Engineering     Channai   20
# The last five columns of the dataframe :
#     ID             Name                  Course        City  Age
# 1   2  Arpanjeet Singh  Electrical Engineering  Chandigarh   19
# 2   3  Ramesh Choudhry  Mechanical Engineering    Amritsar   25
# 3   4     Rama Krishna      BioTech Management      Mumbai   22
# 4   5      Rohit saini    Chemical Engineering     Channai   20
# 5   6     Mohit Pundir    Aerotech Engineering    Bangluru   18
# Structural Information about the DataFrame :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# ...
