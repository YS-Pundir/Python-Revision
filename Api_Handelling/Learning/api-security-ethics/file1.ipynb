# %% [markdown]
# ## API Security and Ethics :
# 1. API Terms of services
# 2. Rate Limiting
# 3. Enviroment Variables for keys
# 4. Data privacy basics
#
# ## This is 4 rules to follow for an engineerwho is consuming any api :
# 1. Security : Protecting ur credentials from unauthorised access .
# 2. Reliablity : rate limiting ---> avoiding excessive request that overload service
# 3. Compliance : Term of service .
# 4. Privacy : ensuring user data is not exposed .

# %% [markdown]
# ## ToS :
# These are the  terms and conditions of using api , which are being determined by the the provider . and needed to be accepte by the builder to use it .
#         1. There can be many examples of this , for exmaple Don't scrape my data.
#         2. Don't store my data in your local machine .
#         3. don't resell data
# ## Rate Limitting  :
#  you can only call the api x times in given time , it is naccesry because if theere si no limit and unlimit aamount of request ha been given to the server , it can crash it . hence it protect fair acces to all users . (Status code=429)When we have 429 status code , it means we have been acceeding the rate limits .

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"MSFT","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": "29d04bb977msh6e6ccf157115028p116a36jsndf3231f7d1da",
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com",
	"Content-Type": "application/json"
}
for i in range(200):
	response = requests.get(url, headers=headers, params=querystring)
	

	print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'MSFT', '3. Last Refreshed': '2026-03-25', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2026-03-25': {'1. open': '376.9200', '2. high': '377.0600', '3. low': '369.6300', '4. close': '371.0400', '5. volume': '31181163'}, '2026-03-24': {'1. open': '382.3600', '2. high': '382.4700', '3. low': '371.8500', '4. close': '372.7400', '5. volume': '42733625'}, '2026-03-23': {'1. open': '383.9000', '2. high': '387.2100', '3. low': '381.6800', '4. close': '383.0000', '5. volume': '29680059'}, '2026-03-20': {'1. open': '386.7900', '2. high': '387.0000', '3. low': '380.1200', '4. close': '381.8700', '5. volume': '50853154'}, '2026-03-19': {'1. open': '390.1000', '2. high': '392.4900', '3. low': '387.0600', '4. close': '389.0200', '5. volume': '25138772'}, '2026-03-18': {'1. open': '397.1250', '2. high': '398.0000', '3. low': '391.0000', '4. close': '391.7900', 
# ...

# %% [markdown]
# ## Enviroment Variables for Api Keys :
# We are not supposed to use  the api key in harcoding , because there is fear of leakage of api key . so it can  be missused by others .
# 1. using the .env file or setx --- "---"
#    (Never commit .env orput it in gitignore file )
