# %% [markdown]
# ### Typical Workflow :
#    1. Data Collection .
#    2. EDA .
#    3. Feature engineering .
#    4. Model Training .
#    5. Evaluate Model .
#
# ### EDA :
#
# 1. understamd the dataset
#        1. what does each column have
#        2. what are various datatyprs
# 2. Inspect the data quality
#       1. Missing values
#       2. incorrect the datatype
#       3. unrealistic values
# 3. Study the distribution
#    it help understand :
#       1. Where most values lies .
#       2. wheather data si skewed
#       3. where extream valeus exist .
#     It is about studing that how data si distributed using the charts .
# 4. Detect an outliers :
#       An outlier is the datapoint which is significantly doffrent from the rest of the Data .
#       It can occur due to :
#       1. Data eentry error .
#       2. measurement mistakes .
#       3. radient events
#       4. froudeint acrtivity .
#       To detect this  , we need to plot it . Best is to plet the box plot .
#
#    * Box plot :
#             1. minimum
#             2. Q1
#             3. midium
#             4. Q3
#             5. Maximum
# 5.  Corelation Heatmap  :
#        It measures how two variable moves together
#     1. It has 3 ranges :
#              1. (-1): negitive  relation.
#              2. (0):no relation.
#              3. (+1):Positive relation.

# %%
import pandas as pd 
import plotly.express as px
df=pd.read_csv("titanic.csv")
corr=df.corr(numeric_only=True)
fig=px.imshow(
    corr,
    title="Correlation of titanic datasset"
)
fig.show()
